# %%
import evidently
import pandas as pd
from sklearn import datasets
from evidently import Dataset
from evidently import DataDefinition
from evidently import Report
from evidently.presets import DataDriftPreset, DataSummaryPreset

adult_data = datasets.fetch_openml(name="adult", version=2, as_frame="auto")
adult = adult_data.frame

# education not in "Some-college", "HS-grad", or "Bachelors"
adult_ref = adult[~adult.education.isin(["Some-college", "HS-grad", "Bachelors"])]

# education in "Some-college", "HS-grad", or "Bachelors"
adult_prod = adult[adult.education.isin(["Some-college", "HS-grad", "Bachelors"])]

schema = DataDefinition(
    numerical_columns=[
        "education-num", "age", "capital-gain",
        "hours-per-week", "capital-loss", "fnlwgt"
    ],
    categorical_columns=[
        "education", "occupation", "native-country", "workclass",
        "marital-status", "relationship", "race", "sex", "class"
    ]
)

eval_data_1 = Dataset.from_pandas(
    pd.DataFrame(adult_prod),
    data_definition=schema
)

eval_data_2 = Dataset.from_pandas(
    pd.DataFrame(adult_ref),
    data_definition=schema
)

report = Report([DataDriftPreset()])
my_eval = report.run(eval_data_1, eval_data_2)
my_eval
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 40
#      34 eval_data_2 = Dataset.from_pandas(
#      35     pd.DataFrame(adult_ref),
#      36     data_definition=schema
#      37 )
#      39 report = Report(DataDriftPreset())
# ---> 40 my_eval = report.run(eval_data_1, eval_data_2)
#      41 my_eval
#
# File ~\anaconda3\envs\comp4948\Lib\site-packages\evidently\core\report.py:964, in Report.run(self, current_data, reference_data, additional_data, timestamp, metadata, tags, name)
#     962     _tags.extend(tags)
#     963 snapshot = Snapshot(self, name, _timestamp, _metadata, _tags)
# --> 964 snapshot.run(current_dataset, reference_dataset, additional_datasets)
#     965 return snapshot
#
# File ~\anaconda3\envs\comp4948\Lib\site-packages\evidently\core\report.py:578, in Snapshot.run(self, current_data, reference_data, additional_data)
# ...
